# %%
# Import requisite packages
import matplotlib
matplotlib.use('Agg') # Run before importing matplotlib.pyplot or pylab!
import matplotlib.pyplot as plt
import hddm
import pandas as pd
import pickle
from patsy import dmatrix
from kabuki.analyze import gelman_rubin
from kabuki.utils import concat_models
import pathlib
import numpy as np
import warnings

# %%
print(hddm.__version__)
# Out:
# 0.9.7

# %%
# Load data from csv file into a NumPy structured array
data = hddm.load_csv('DDM_data_tms.csv')  # Change this!
data.visit.unique()
# Out:
# array([1, 2, 3, 4])

# %%
data.cond.unique()
# Out:
# array(['Dual', 'Delay', 'Switch', 'Base'], dtype=object)

# %%
data=data[data.visit==2]
print(data.tail(5))
# Out:
#        subj_idx  visit  response      rt  acc  cond ctrl
# 12659        16      2       0.0  0.4634    1  Base   LL
# 12660        16      2       0.0  0.3033    1  Base   LL
# 12661        16      2       0.0  0.3175    1  Base   LL
# 12662        16      2       1.0  0.6147    1  Base   LL
# 12663        16      2       1.0  0.5879    1  Base   LL

# %%
# Name this model
modelName = 'm04_va_visit2'  # Change this!

# %%
# Check whether save directories exist; if not, create them
pathlib.Path('./Models/').mkdir(parents=True, exist_ok=True)
pathlib.Path('./Results/').mkdir(parents=True, exist_ok=True)
pathlib.Path('./Plots/' + modelName).mkdir(parents=True, exist_ok=True)

# %%
models = []
for i in range(5):
    m = hddm.HDDMRegressor(data,
        # Change this!
        {"v ~ C(cond, Treatment('Base'))",
        "a ~ C(cond, Treatment('Base'))"},
        group_only_regressors=True,
        p_outlier=.05,
        include={'z'})
                           

    m.find_starting_values()
    m.sample(2200, burn=200, dbname='./Models/'+modelName+'_%s.db'%i, db='pickle')
    m.save('./Models/'+modelName+'_%s'%i)
    models.append(m)
# Out:
# No model attribute --> setting up standard HDDM
# Set model to ddm
# /Users/jongminlee/opt/anaconda3/envs/onlyhddm/lib/python3.6/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 2201 of 2200 complete in 1224.3 secNo model attribute --> setting up standard HDDM
# Set model to ddm
# /Users/jongminlee/opt/anaconda3/envs/onlyhddm/lib/python3.6/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 2201 of 2200 complete in 1270.3 secNo model attribute --> setting up standard HDDM
# Set model to ddm
# /Users/jongminlee/opt/anaconda3/envs/onlyhddm/lib/python3.6/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 2201 of 2200 complete in 1234.5 secNo model attribute --> setting up standard HDDM
# Set model to ddm
# /Users/jongminlee/opt/anaconda3/envs/onlyhddm/lib/python3.6/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 2201 of 2200 complete in 1222.4 secNo model attribute --> setting up standard HDDM
# Set model to ddm
# /Users/jongminlee/opt/anaconda3/envs/onlyhddm/lib/python3.6/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 2201 of 2200 complete in 1240.7 sec

# %%
# Calculate Gelman-Rubin r-hat statistic
m_rhat = gelman_rubin(models)
pd.DataFrame.from_dict(m_rhat, orient='index').to_csv('./Results/'+modelName+'_RHat.csv')


# Save traces of concatenated model (only valid to look at if converged!)
m_comb = concat_models(models)
m_comb_export = m_comb.get_traces()
m_comb_export.to_csv('./Results/'+modelName+'_traces.csv')

# %%
# List figures to be saved
# Change this!
convergeCheck = [
't', 't_std',
'z', 'z_std',

'v_Intercept', 'v_Intercept_std',
'a_Intercept', 'a_Intercept_std',

'v_C(cond, Treatment(\'Base\'))[T.Dual]',
'v_C(cond, Treatment(\'Base\'))[T.Delay]',
'v_C(cond, Treatment(\'Base\'))[T.Switch]',

'a_C(cond, Treatment(\'Base\'))[T.Dual]',
'a_C(cond, Treatment(\'Base\'))[T.Delay]',
'a_C(cond, Treatment(\'Base\'))[T.Switch]'
]

# Save convergence figures
for i in convergeCheck:
    fig = m_comb.plot_posteriors(i)
    plt.savefig('./Plots/' + modelName + '/' + i + '.pdf')



#####
#####  GET DIC
#####

print("DIC: %f" %m_comb.dic)
# Out:
# Plotting t
# Plotting t_std
# Plotting z
# Plotting z_std
# Plotting v_Intercept
# Plotting v_Intercept_std
# Plotting a_Intercept
# Plotting a_Intercept_std
# Plotting v_C(cond, Treatment('Base'))[T.Dual]
# Plotting v_C(cond, Treatment('Base'))[T.Delay]
# Plotting v_C(cond, Treatment('Base'))[T.Switch]
# Plotting a_C(cond, Treatment('Base'))[T.Dual]
# Plotting a_C(cond, Treatment('Base'))[T.Delay]
# Plotting a_C(cond, Treatment('Base'))[T.Switch]
# DIC: 1910.959642

# %%
plt.close('all')

# %%
# Name this model
modelName = 'm04_va_visit2'  # Change this!

# Load previously estimated models
m0 = pickle.load(open('./Models/'+modelName+'_0', 'rb'))
m1 = pickle.load(open('./Models/'+modelName+'_1', 'rb'))
m2 = pickle.load(open('./Models/'+modelName+'_2', 'rb'))
m3 = pickle.load(open('./Models/'+modelName+'_3', 'rb'))
m4 = pickle.load(open('./Models/'+modelName+'_4', 'rb'))

# Combine traces
models = [m0, m1, m2, m3, m4]
m_comb = concat_models(models)
print("DIC: %f" %m_comb.dic)
# Out:
# DIC: 1910.959642

# %%
m_comb.nodes_db.node.unique()
# Out:
# array([<pymc.distributions.new_dist_class.<locals>.new_class 't' at 0x7fd9da05cf60>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_std' at 0x7fd9f940e3c8>,
#        <pymc.PyMCObjects.Deterministic 't_rate' at 0x7fd9d9ee20b8>,
#        <pymc.PyMCObjects.Deterministic 't_shape' at 0x7fd9d9ee2ef0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.1' at 0x7fd9abb76b70>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.2' at 0x7fd9adebd2e8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.3' at 0x7fd9d9ee22e8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.4' at 0x7fd9abb76668>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.5' at 0x7fd9adebd860>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.6' at 0x7fd9abb76978>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.7' at 0x7fd9abb768d0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.8' at 0x7fd9abb76940>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.9' at 0x7fd9abb76ef0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.10' at 0x7fd9abb76160>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.11' at 0x7fd9abb76e10>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.12' at 0x7fd9abb76080>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.13' at 0x7fd9abb76e80>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.14' at 0x7fd9abb76390>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.15' at 0x7fd9abb76908>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.16' at 0x7fd9abb76cc0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.17' at 0x7fd9abb769e8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_trans' at 0x7fd9d9ecc908>,
#        <pymc.PyMCObjects.Deterministic 'z' at 0x7fd9da05c1d0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_std' at 0x7fd9d9c175f8>,
#        <pymc.PyMCObjects.Deterministic 'z_tau' at 0x7fd9d9b52710>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.1' at 0x7fd9aba80e80>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.2' at 0x7fd9d9c179e8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.3' at 0x7fd9d9cd6940>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.4' at 0x7fd9aba80208>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.5' at 0x7fd9d9b52160>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.6' at 0x7fd9aba808d0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.7' at 0x7fd9aba80940>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.8' at 0x7fd9aba80358>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.9' at 0x7fd9aba80240>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.10' at 0x7fd9aba80da0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.11' at 0x7fd9aba80b00>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.12' at 0x7fd9aba80048>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.13' at 0x7fd9aba804e0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.14' at 0x7fd9aba80128>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.15' at 0x7fd9aba803c8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.16' at 0x7fd9aba80be0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'z_subj_trans.17' at 0x7fd9aba80a20>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.1' at 0x7fd9aba80080>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.2' at 0x7fd9aba80cf8>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.3' at 0x7fd9aba801d0>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.4' at 0x7fd9aba809e8>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.5' at 0x7fd9d9b52358>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.6' at 0x7fd9db204860>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.7' at 0x7fd9da072390>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.8' at 0x7fd9da3a8588>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.9' at 0x7fd9da3a8d30>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.10' at 0x7fd9da3a89b0>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.11' at 0x7fd9da3a8f28>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.12' at 0x7fd9da3a8898>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.13' at 0x7fd9da3a8f98>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.14' at 0x7fd9da3a8400>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.15' at 0x7fd9da3a82e8>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.16' at 0x7fd9da3a8908>,
#        <pymc.PyMCObjects.Deterministic 'z_subj.17' at 0x7fd9da3a88d0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept' at 0x7fd9daa9a198>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_std' at 0x7fd9db7642b0>,
#        <pymc.PyMCObjects.Deterministic 'a_Intercept_rate' at 0x7fd9b00e0860>,
#        <pymc.PyMCObjects.Deterministic 'a_Intercept_shape' at 0x7fd9b00e0b70>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.1' at 0x7fd9dba08ba8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.2' at 0x7fd9dba08898>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.3' at 0x7fd9dab10278>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.4' at 0x7fd9dba089b0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.5' at 0x7fd9b00e05c0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.6' at 0x7fd9b00e0eb8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.7' at 0x7fd9da9ed1d0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.8' at 0x7fd9da9ed390>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.9' at 0x7fd9da9ed630>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.10' at 0x7fd9da9ed0f0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.11' at 0x7fd9da9ed320>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.12' at 0x7fd9da9eda20>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.13' at 0x7fd9da9ed240>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.14' at 0x7fd9da9ed160>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.15' at 0x7fd9da9ed278>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.16' at 0x7fd9abceed68>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_Intercept_subj.17' at 0x7fd9abcee4a8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_C(cond, Treatment('Base'))[T.Delay]' at 0x7fd9ac4fb208>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_C(cond, Treatment('Base'))[T.Dual]' at 0x7fd9ac4fbdd8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'a_C(cond, Treatment('Base'))[T.Switch]' at 0x7fd9ac4e1b70>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.1' at 0x7fd9aba80860>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.2' at 0x7fd9b00e0b38>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.3' at 0x7fd9aba5d2e8>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.4' at 0x7fd9aba237b8>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.5' at 0x7fd9b00df278>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.6' at 0x7fd9b00df470>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.7' at 0x7fd9ab9e78d0>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.8' at 0x7fd9ab9e7278>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.9' at 0x7fd9d9f186d8>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.10' at 0x7fd9d9f393c8>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.11' at 0x7fd9d9f48710>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.12' at 0x7fd9dbf46320>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.13' at 0x7fd9dbf20c50>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.14' at 0x7fd9dbf20240>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.15' at 0x7fd9dbf208d0>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.16' at 0x7fd9dbf20160>,
#        <pymc.PyMCObjects.Deterministic 'a_reg.17' at 0x7fd9dbe6d518>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept' at 0x7fd9b00eb630>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_std' at 0x7fd9dc253978>,
#        <pymc.PyMCObjects.Deterministic 'v_Intercept_tau' at 0x7fd9dc253c50>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.1' at 0x7fd9dbe6d7b8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.2' at 0x7fd9dc253518>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.3' at 0x7fd9da9ed518>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.4' at 0x7fd9dbe6dc18>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.5' at 0x7fd9dc253710>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.6' at 0x7fd9dbe6d278>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.7' at 0x7fd9dbe6d1d0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.8' at 0x7fd9dbe6df98>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.9' at 0x7fd9dbe6d400>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.10' at 0x7fd9dbe6d198>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.11' at 0x7fd9dafd6320>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.12' at 0x7fd9dafd69e8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.13' at 0x7fd9dafd6780>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.14' at 0x7fd9dafd6048>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.15' at 0x7fd9dafd6358>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.16' at 0x7fd9dafd6630>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_Intercept_subj.17' at 0x7fd9dafd6160>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_C(cond, Treatment('Base'))[T.Delay]' at 0x7fd9ade9a860>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_C(cond, Treatment('Base'))[T.Dual]' at 0x7fd9f940e048>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'v_C(cond, Treatment('Base'))[T.Switch]' at 0x7fd9f940e5c0>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.1' at 0x7fd9dbe4fe10>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.2' at 0x7fd9dc253400>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.3' at 0x7fd9dbe4f2b0>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.4' at 0x7fd9dbe4f2e8>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.5' at 0x7fd9dbcf50b8>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.6' at 0x7fd9dbcf5f98>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.7' at 0x7fd9dbcf5048>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.8' at 0x7fd9dbce4dd8>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.9' at 0x7fd9dbce41d0>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.10' at 0x7fd9dbce4860>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.11' at 0x7fd9dbce42e8>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.12' at 0x7fd9dbccb7b8>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.13' at 0x7fd9dbccbe48>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.14' at 0x7fd9dbccb0b8>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.15' at 0x7fd9dbcbb400>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.16' at 0x7fd9dbcbb128>,
#        <pymc.PyMCObjects.Deterministic 'v_reg.17' at 0x7fd9dbcbb1d0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.1' at 0x7fd9dbb45550>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.2' at 0x7fd9dbb454e0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.3' at 0x7fd9dbc195c0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.4' at 0x7fd9dbc19940>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.5' at 0x7fd9dbc19da0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.6' at 0x7fd9dbc19898>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.7' at 0x7fd9dbc192e8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.8' at 0x7fd9dbc19208>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.9' at 0x7fd9dbc19080>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.10' at 0x7fd9dad45b38>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.11' at 0x7fd9dad45da0>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.12' at 0x7fd9dad45a20>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.13' at 0x7fd9dad454a8>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.14' at 0x7fd9dad45518>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.15' at 0x7fd9dad45080>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.16' at 0x7fd9dad2f748>,
#        <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt.17' at 0x7fd9dad2fd68>],
#       dtype=object)

# %%
# %matplotlib inline
regression_v_0 = m_comb.nodes_db.node[
    'v_C(cond, Treatment(\'Base\'))[T.Delay]'
]
regression_v_1 = m_comb.nodes_db.node[
    'v_C(cond, Treatment(\'Base\'))[T.Dual]'
]
regression_v_2 = m_comb.nodes_db.node[
    'v_C(cond, Treatment(\'Base\'))[T.Switch]'
]
regression_v_3 = m_comb.nodes_db.node[
    'v_Intercept'
]


# Plot posteriors
hddm.analyze.plot_posterior_nodes(
    [
     regression_v_0,
     regression_v_1,
     regression_v_2,
     regression_v_3
    ]
)

print("P_v(Delay > Base) = ", (regression_v_0.trace() > 0).mean())
print("P_v(Delay > Base) = ", (regression_v_0.trace() < 0).mean())
print("P_v(Dual > Base) = ", (regression_v_1.trace() > 0).mean())
print("P_v(Dual > Base) = ", (regression_v_1.trace() < 0).mean())
print("P_v(Switch > Base) = ", (regression_v_2.trace() > 0).mean())
print("P_v(Switch > Base) = ", (regression_v_2.trace() < 0).mean())
# print("P_v(Delay > Dual) = ", (regression_v_0.trace() > regression_v_1.trace()).mean())
# print("P_v(Delay > Switch) = ", (regression_v_0.trace() > regression_v_2.trace()).mean())
# Out:
# P_v(Delay > Base) =  1.0
# P_v(Delay > Base) =  0.0
# P_v(Dual > Base) =  0.5212
# P_v(Dual > Base) =  0.4788
# P_v(Switch > Base) =  0.4042
# P_v(Switch > Base) =  0.5958

# %%
regression_a_0 = m_comb.nodes_db.node[
    'a_C(cond, Treatment(\'Base\'))[T.Delay]'
]
regression_a_1 = m_comb.nodes_db.node[
    'a_C(cond, Treatment(\'Base\'))[T.Dual]'
]
regression_a_2 = m_comb.nodes_db.node[
    'a_C(cond, Treatment(\'Base\'))[T.Switch]'
]
regression_a_3 = m_comb.nodes_db.node[
    'a_Intercept'
]

# Plot posteriors
hddm.analyze.plot_posterior_nodes(
    [
     regression_a_0,
     regression_a_1,
     regression_a_2,
     regression_a_3
    ]
)

# %%
pwd
# Out:
# '/Users/jongminlee/Desktop/Files/nee_lab/DDM/tms'

# %%
v_Dual, v_Base, v_Delay, v_Switch=m_comb.nodes_db.node[['v_C(cond, Treatment(\'Base\'))[T.Dual]', 
                                                        'v_Intercept', 
                                                        'v_C(cond, Treatment(\'Base\'))[T.Switch]', 
                                                        'v_C(cond)[Switch]']]
print("P_v(Dual > Base) = ", (v_Dual.trace() > v_Base.trace()).mean())
print("P_v(Delay > Base) = ", (v_Delay.trace() > v_Base.trace()).mean())
print("P_v(Delay > Dual) = ", (v_Delay.trace() > v_Dual.trace()).mean())
print("P_v(Delay > Switch) = ", (v_Delay.trace() > v_Switch.trace()).mean())

print("P_v(Dual < Base) = ", (v_Dual.trace() < v_Base.trace()).mean())
print("P_v(Delay < Base) = ", (v_Delay.trace() < v_Base.trace()).mean())
print("P_v(Delay < Dual) = ", (v_Delay.trace() < v_Dual.trace()).mean())
print("P_v(Delay < Switch) = ", (v_Delay.trace() < v_Switch.trace()).mean())

# %%
m0.plot_posterior_predictive(figsize=(14,10))

# %%
warnings.filterwarnings('ignore')

# %%
print(m_comb.nodes_db)
# Out:
#          knode_name stochastic observed   subj      node tag     depends  \
# t                 t       True    False  False         t  ()          []
# t_std         t_std       True    False  False     t_std  ()          []
# t_rate       t_rate      False    False  False    t_rate  ()          []
# t_shape     t_shape      False    False  False   t_shape  ()          []
# t_subj.1     t_subj       True    False   True  t_subj.1  ()  [subj_idx]
# ...             ...        ...      ...    ...       ...  ..         ...
# wfpt.13        wfpt      False     True  False   wfpt.13  ()  [subj_idx]
# wfpt.14        wfpt      False     True  False   wfpt.14  ()  [subj_idx]
# wfpt.15        wfpt      False     True  False   wfpt.15  ()  [subj_idx]
# wfpt.16        wfpt      False     True  False   wfpt.16  ()  [subj_idx]
# wfpt.17        wfpt      False     True  False   wfpt.17  ()  [subj_idx]
#
#          hidden subj_idx visit  ... cond ctrl       mean         std  \
# t         False      NaN   NaN  ...  NaN  NaN   0.245341    0.009984
# t_std     False      NaN   NaN  ...  NaN  NaN  0.0392868  0.00848703
# t_rate     True      NaN   NaN  ...  NaN  NaN        NaN         NaN
# t_shape    True      NaN   NaN  ...  NaN  NaN        NaN         NaN
# t_subj.1  False        1   NaN  ...  NaN  NaN   0.322208   0.0187865
# ...         ...      ...   ...  ...  ...  ...        ...         ...
# wfpt.13   False       13   NaN  ...  NaN  NaN        NaN         NaN
# wfpt.14   False       14   NaN  ...  NaN  NaN        NaN         NaN
# wfpt.15   False       15   NaN  ...  NaN  NaN        NaN         NaN
# wfpt.16   False       16   NaN  ...  NaN  NaN        NaN         NaN
# wfpt.17   False       17   NaN  ...  NaN  NaN        NaN         NaN
#
#               2.5q        25q        50q        75q      97.5q       mc err
# t         0.226553   0.238852    0.24485   0.251502   0.266415  0.000140138
# t_std     0.026222  0.0333644  0.0380781  0.0438261  0.0590163  0.000145351
# t_rate         NaN        NaN        NaN        NaN        NaN          NaN
# t_shape        NaN        NaN        NaN        NaN        NaN          NaN
# t_subj.1  0.279317   0.312103   0.325719   0.333932   0.352592  0.000381851
# ...            ...        ...        ...        ...        ...          ...
# wfpt.13        NaN        NaN        NaN        NaN        NaN          NaN
# wfpt.14        NaN        NaN        NaN        NaN        NaN          NaN
# wfpt.15        NaN        NaN        NaN        NaN        NaN          NaN
# wfpt.16        NaN        NaN        NaN        NaN        NaN          NaN
# wfpt.17        NaN        NaN        NaN        NaN        NaN          NaN
#
# [157 rows x 23 columns]

# %%
hddm.analyze.plot_posterior_nodes(m_comb.nodes_db.loc[['v_C(cond, Treatment(\'Base\'))[T.Delay]', 
                                                       'v_C(cond, Treatment(\'Base\'))[T.Dual]',
                                                      'v_C(cond, Treatment(\'Base\'))[T.Switch]',
                                                      'v_Intercept'], 'node'])

# %%
import pymc as pm
import numpy as np
import pymc.progressbar as pbar

def _parents_to_random_posterior_sample(bottom_node, pos=None):
    """Walks through parents and sets them to pos sample."""
    for i, parent in enumerate(bottom_node.extended_parents):
        if not isinstance(parent, pm.Node): # Skip non-stochastic nodes
            continue

        if pos is None:
            # Set to random posterior position
            pos = np.random.randint(0, len(parent.trace()))

        assert len(parent.trace()) >= pos, "pos larger than posterior sample size"
        parent.value = parent.trace()[pos]

def _post_pred_generate(bottom_node, samples=500, data=None, append_data=True):
    """Generate posterior predictive data from a single observed node."""
    datasets = []
    ##############################
    # Sample and generate stats
    for sample in range(samples):
        _parents_to_random_posterior_sample(bottom_node)
        # Generate data from bottom node
        sampled_data = bottom_node.random()
        sampled_data.reset_index(inplace=True)
        if append_data and data is not None:
            sampled_data = sampled_data.join(data.reset_index(), lsuffix='_sampled')
        datasets.append(sampled_data)
    return datasets

def post_pred_gen(model, groupby=None, samples=500, append_data=False, progress_bar=True):
    results = {}

    # Progress bar
    if progress_bar:
        n_iter = len(model.get_observeds())
        bar = pbar.progress_bar(n_iter)
        bar_iter = 0
    else:
        print("Sampling...")

    if groupby is None:
        iter_data = ((name, model.data.loc[obs['node'].value.index]) for name, obs in model.iter_observeds())
    else:
        iter_data = model.data.groupby(groupby)

    for name, data in iter_data:
        node = model.get_data_nodes(data.index)

        if progress_bar:
            bar_iter += 1
            bar.update(bar_iter)

        if node is None or not hasattr(node, 'random'):
            continue # Skip

        ##############################
        # Sample and generate stats
        datasets = _post_pred_generate(node, samples=samples, data=data, append_data=append_data)
        results[name] = pd.concat(datasets, names=['sample'], keys=list(range(len(datasets))))

    if progress_bar:
        bar_iter += 1
        bar.update(bar_iter)

    return pd.concat(results, names=['node'])

# %%
# Generate predicted results from previously-estimated models
# Normally, we'd want to get many, many samples - I've done 1000 in the past
# But, for the sake of time, let's just do a couple

ppc_data = post_pred_gen(m_comb, samples=1000, append_data=True)
ppc_data.to_csv('./PPC/'+modelName+'_simul_ppc-visit2.csv')
ppc_data

# ppc_data = post_pred_gen(m_comb)
# ppc_data.to_csv('./PPC/regression_ppc4.csv')
# Out:
#  [--------------------117%--------------------] 20 of 17 complete in 84.2 sec

# %%
ppc_compare = hddm.utils.post_pred_stats(data, ppc_data, call_compare=False)
print(ppc_compare.head())
# Out:
#                accuracy   mean_ub    std_ub   10q_ub   30q_ub  50q_ub  \
# node   sample
# wfpt.1 0       0.359375  0.687104  0.263433  0.49894  0.54466  0.6202
#        1       0.359375  0.687104  0.263433  0.49894  0.54466  0.6202
#        2       0.359375  0.687104  0.263433  0.49894  0.54466  0.6202
#        3       0.359375  0.687104  0.263433  0.49894  0.54466  0.6202
#        4       0.359375  0.687104  0.263433  0.49894  0.54466  0.6202
#
#                 70q_ub   90q_ub   mean_lb    std_lb   10q_lb   30q_lb  50q_lb  \
# node   sample
# wfpt.1 0       0.69782  0.93738 -0.669598  0.318255  0.38904  0.47188  0.5955
#        1       0.69782  0.93738 -0.669598  0.318255  0.38904  0.47188  0.5955
#        2       0.69782  0.93738 -0.669598  0.318255  0.38904  0.47188  0.5955
#        3       0.69782  0.93738 -0.669598  0.318255  0.38904  0.47188  0.5955
#        4       0.69782  0.93738 -0.669598  0.318255  0.38904  0.47188  0.5955
#
#                 70q_lb  90q_lb
# node   sample
# wfpt.1 0       0.72234   1.062
#        1       0.72234   1.062
#        2       0.72234   1.062
#        3       0.72234   1.062
#        4       0.72234   1.062

# %%
ppc_compare
# Out:
#                 accuracy   mean_ub    std_ub   10q_ub   30q_ub  50q_ub  \
# node    sample
# wfpt.1  0       0.359375  0.687104  0.263433  0.49894  0.54466  0.6202
#         1       0.359375  0.687104  0.263433  0.49894  0.54466  0.6202
#         2       0.359375  0.687104  0.263433  0.49894  0.54466  0.6202
#         3       0.359375  0.687104  0.263433  0.49894  0.54466  0.6202
#         4       0.359375  0.687104  0.263433  0.49894  0.54466  0.6202
# ...                  ...       ...       ...      ...      ...     ...
# wfpt.17 995     0.625000  0.504744  0.224950  0.26743  0.35604  0.4719
#         996     0.625000  0.504744  0.224950  0.26743  0.35604  0.4719
#         997     0.625000  0.504744  0.224950  0.26743  0.35604  0.4719
#         998     0.625000  0.504744  0.224950  0.26743  0.35604  0.4719
#         999     0.625000  0.504744  0.224950  0.26743  0.35604  0.4719
#
#                  70q_ub   90q_ub   mean_lb    std_lb   10q_lb   30q_lb  \
# node    sample
# wfpt.1  0       0.69782  0.93738 -0.669598  0.318255  0.38904  0.47188
#         1       0.69782  0.93738 -0.669598  0.318255  0.38904  0.47188
#         2       0.69782  0.93738 -0.669598  0.318255  0.38904  0.47188
#         3       0.69782  0.93738 -0.669598  0.318255  0.38904  0.47188
#         4       0.69782  0.93738 -0.669598  0.318255  0.38904  0.47188
# ...                 ...      ...       ...       ...      ...      ...
# wfpt.17 995     0.56934  0.73676 -0.416835  0.116639  0.30710  0.34967
#         996     0.56934  0.73676 -0.416835  0.116639  0.30710  0.34967
#         997     0.56934  0.73676 -0.416835  0.116639  0.30710  0.34967
#         998     0.56934  0.73676 -0.416835  0.116639  0.30710  0.34967
#         999     0.56934  0.73676 -0.416835  0.116639  0.30710  0.34967
#
#                 50q_lb   70q_lb   90q_lb
# node    sample
# wfpt.1  0       0.5955  0.72234  1.06200
#         1       0.5955  0.72234  1.06200
#         2       0.5955  0.72234  1.06200
#         3       0.5955  0.72234  1.06200
#         4       0.5955  0.72234  1.06200
# ...                ...      ...      ...
# wfpt.17 995     0.3739  0.45119  0.53717
#         996     0.3739  0.45119  0.53717
#         997     0.3739  0.45119  0.53717
#         998     0.3739  0.45119  0.53717
#         999     0.3739  0.45119  0.53717
#
# [17000 rows x 15 columns]

# %%
hddm.utils.post_pred_stats(data, ppc_data)
# Out:
#           observed      mean       std           SEM       MSE credible  \
# stat
# accuracy  0.543811  0.543811  0.142737  2.185445e-15  0.020374     True
# mean_ub   0.526301  0.529962  0.070096  1.339605e-05  0.004927     True
# std_ub    0.208366  0.193519  0.063689  2.204281e-04  0.004277     True
# 10q_ub    0.319740  0.334811  0.052396  2.271396e-04  0.002972     True
# 30q_ub    0.410820  0.416362  0.050482  3.071825e-05  0.002579     True
# 50q_ub    0.492600  0.498682  0.059709  3.699534e-05  0.003602     True
# 70q_ub    0.577460  0.584432  0.082400  4.861385e-05  0.006838     True
# 90q_ub    0.758120  0.744916  0.119130  1.743482e-04  0.014366     True
# mean_lb  -0.545084 -0.533342  0.084047  1.378695e-04  0.007202     True
# std_lb    0.250766  0.202686  0.083492  2.311678e-03  0.009283     True
# 10q_lb    0.332600  0.348934  0.047687  2.668042e-04  0.002541     True
# 30q_lb    0.410800  0.421335  0.047701  1.109796e-04  0.002386     True
# 50q_lb    0.478300  0.490679  0.083922  1.532506e-04  0.007196     True
# 70q_lb    0.580750  0.562951  0.098592  3.168013e-04  0.010037     True
# 90q_lb    0.816400  0.751951  0.175298  4.153653e-03  0.034883     True
#
#            quantile   mahalanobis
# stat
# accuracy  35.294117  3.275157e-07
# mean_ub   58.823528  5.221484e-02
# std_ub    64.705879  2.331127e-01
# 10q_ub    47.058823  2.876398e-01
# 30q_ub    64.705879  1.097888e-01
# 50q_ub    58.823528  1.018662e-01
# 70q_ub    58.823528  8.461627e-02
# 90q_ub    64.705879  1.108380e-01
# mean_lb   35.294117  1.397045e-01
# std_lb    70.588234  5.758651e-01
# 10q_lb    35.294117  3.425283e-01
# 30q_lb    41.176472  2.208499e-01
# 50q_lb    47.058823  1.475108e-01
# 70q_lb    64.705879  1.805308e-01
# 90q_lb    64.705879  3.676529e-01

# %%
ppc_data.head(10)
# Out:
#                  index_sampled  rt_sampled  response_sampled  index  subj_idx  \
# node   sample
# wfpt.1 0      0              0   -1.858070                 0    190         1
#               1              1   -0.454054                 0    191         1
#               2              2   -0.718052                 0    192         1
#               3              3   -0.788052                 0    193         1
#               4              4   -2.631069                 0    194         1
#               5              5   -0.709053                 0    195         1
#               6              6   -0.898050                 0    196         1
#               7              7   -0.722052                 0    197         1
#               8              8    0.764052                 1    198         1
#               9              9   -0.539054                 0    199         1
#
#                  visit  response      rt  acc  cond ctrl
# node   sample
# wfpt.1 0      0      2       0.0 -1.0701    1  Dual   HH
#               1      2       1.0  0.7973    1  Dual   HH
#               2      2       1.0  0.6202    1  Dual   HH
#               3      2       1.0  0.5195    1  Dual   HH
#               4      2       1.0  1.8293    0  Dual   HH
#               5      2       1.0  0.6914    1  Dual   HH
#               6      2       1.0  0.5264    1  Dual   HH
#               7      2       0.0 -0.7256    1  Dual   HH
#               8      2       1.0  0.6497    1  Dual   HH
#               9      2       0.0 -0.8709    1  Dual   HH

# %%
ppc_compare.to_csv('./PPC/'+modelName+'_va_PPC_stats.csv')
